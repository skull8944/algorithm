# %% [markdown]
# <a href="https://colab.research.google.com/github/skull8944/algorithm/blob/master/1209_dp.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# 斜體文字![dp.png](data:image/png;base64,...)

# %%
#dp切鐵條
def CutRod(price, n):
  r = [0] * (n+1) #記切幾個的最大
  if n == 1:
    print("最高可賣",p[n], "元")
  else:
    for i in range(1, n+1):
      for j in range(1, i+1):
        q = max(p[i], r[j]+r[i-j])
        if q > r[i]:
          r[i] = q
    print("最高可賣", r[i], "元")
p = [0, 1, 5, 8, 9, 10 ,17, 17, 20, 25, 30]
while True:
  n = input("請輸入鐵條長度(1~10):")
  if n.isdigit():
    n = int(n)
    if n <= 10 and n >= 1:
      break 
CutRod(p,n)
# Out:
# 請輸入鐵條長度(1~10):7
# 最高可賣 18 元
